# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
df2=pd.read_csv('Iris.csv')
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#df2.shape
df2.shape[0]
#df2.shape[1]
# Out:
# 150

# %%
df2.head(7)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
# Load the Iris dataset
iris = load_iris()

# Print the keys of the Iris dataset
print("Keys in Iris dataset:", iris.keys())

# Print the number of rows and columns in the data
n_samples, n_features = iris.data.shape
print(f"Number of rows (samples): {n_samples}")
print(f"Number of columns (features): {n_features}")

# Print the feature names
print("Feature names:")
for feature_name in iris.feature_names:
    print("-", feature_name)

# Print the description of the Iris dataset
print("Iris dataset description:")
print(iris.DESCR)
# Out:
# Keys in Iris dataset: dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# Number of rows (samples): 150
# Number of columns (features): 4
# Feature names:
# - sepal length (cm)
# - sepal width (cm)
# - petal length (cm)
# - petal width (cm)
# Iris dataset description:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#len(df2)
len(df2.columns)
#len(df2.axes)
# Out:
# 6

# %%
df2.shape
# Out:
# (150, 6)

# %%
df2.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Perform one-hot encoding on the 'species' column
df2_encoded = pd.get_dummies(df2, columns=['Species'])

# Display the DataFrame with one-hot encoding
print(df2_encoded)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                      1                        0                       0
# ...

# %%
df2.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Drop the "id" column for each species
df2_setosa = df2[df2['Species'] == 'setosa'].drop(columns=['Id'])
df2_versicolor = df2[df2['Species'] == 'versicolor'].drop(columns=['Id'])
df2_virginica = df2[df2['Species'] == 'virginica'].drop(columns=['Id'])

# Display or save the modified DataFrames as needed
print("Iris Data Without 'Id' column for Setosa:")
print(df2_setosa)

print("\nIris Data Without 'Id' column for Versicolor:")
print(df2_versicolor)

print("\nIris Data Without 'Id' column for Virginica:")
print(df2_virginica)
# Out:
# Iris Data Without 'Id' column for Setosa:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
#
# Iris Data Without 'Id' column for Versicolor:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
#
# Iris Data Without 'Id' column for Virginica:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
